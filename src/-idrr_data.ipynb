# %%
import pandas as pd
from IDRR_data import *

# %%
data_path = r'D:\ZpWang\Projects\02.01-IDRR_data\data\used\pdtb3.p2.csv'
df = IDRRDataFrames(
    data_name='pdtb2',
    data_level='top',
    data_relation='Implicit',
    data_path=data_path,
)

# %%
df.train_df.columns
# Out:
# Index(['arg1', 'arg2', 'conn1', 'conn2', 'conn1sense1', 'conn1sense2',
#        'conn2sense1', 'conn2sense2', 'relation', 'split', 'section',
#        'file_name', 'data_id', 'label11', 'label11id', 'label12', 'label12id',
#        'label21', 'label21id', 'label22', 'label22id', 'ans_word1',
#        'ans_word1id', 'ans_word2', 'ans_word2id'],
#       dtype='object')

# %%
df.train_df.iloc[0]
# Out:
# arg1           In an Oct. 19 review of "The Misanthrope" at C...
# arg2                                      Ms. Haag plays Elianti
# conn1                                                    in fact
# conn2                                                        NaN
# conn1sense1             Expansion.Level-of-detail.Arg2-as-detail
# conn1sense2                                                  NaN
# conn2sense1                                                  NaN
# conn2sense2                                                  NaN
# relation                                                Implicit
# split                                                      train
# section                                                        2
# file_name                                               wsj_0200
# data_id                                                     3598
# label11                                                Expansion
# ...

# %%
df.train_df.iloc[0]['conn1sense1']
# Out:
# 'Expansion.Level-of-detail.Arg2-as-detail'

# %%
idrr_di = IDRRDataIter(df.train_df)
idrr_di = df.train_di
idrr_di[0].dic
# Out:
# {'arg1': 'In an Oct. 19 review of "The Misanthrope" at Chicago\'s Goodman Theatre ("Revitalized Classics Take the Stage in Windy City," Leisure & Arts), the role of Celimene, played by Kim Cattrall, was mistakenly attributed to Christina Haag',
#  'arg2': 'Ms. Haag plays Elianti',
#  'conn1': 'in fact',
#  'conn2': None,
#  'conn1sense1': 'Expansion.Level-of-detail.Arg2-as-detail',
#  'conn1sense2': None,
#  'conn2sense1': None,
#  'conn2sense2': None,
#  'relation': 'Implicit',
#  'split': 'train',
#  'data_id': 3598,
#  'label11': 'Expansion',
#  'label11id': 2,
#  'label12': None,
#  'label12id': None,
#  'label21': None,
#  'label21id': None,
#  'label22': None,
#  'label22id': None,
#  'ans_word1': 'and',
#  'ans_word1id': 11,
#  'ans_word2': None,
#  'ans_word2id': None}
